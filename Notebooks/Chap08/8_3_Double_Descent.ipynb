# %% [markdown]
# <a href="https://colab.research.google.com/github/fredhsu/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-4au3x1gy
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-4au3x1gy
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=415a0e57daee3f954213c4a8d7da99660ead40ed7b65730cf97c2eee0839d9cb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jkhw0yt_/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.242841, train error 82.47,  test loss 2.231825, test error 81.62
# Epoch   100, train loss 1.910248, train error 72.53,  test loss 1.759269, test error 70.05
# Epoch   200, train loss 1.889212, train error 71.18,  test loss 1.738110, test error 68.88
# Epoch   300, train loss 1.887930, train error 70.90,  test loss 1.729468, test error 68.78
# Epoch   400, train loss 1.886523, train error 70.72,  test loss 1.723411, test error 68.80
# Epoch   500, train loss 1.885277, train error 70.20,  test loss 1.722128, test error 68.45
# Epoch   600, train loss 1.888129, train error 71.15,  test loss 1.723938, test error 68.85
# Epoch   700, train loss 1.885965, train error 71.55,  test loss 1.720069, test error 69.10
# Epoch   800, train loss 1.886951, train error 71.45,  test loss 1.726010, test error 69.05
# Epoch   900, train loss 1.886914, train error 71.80,  test loss 1.724211, test error 69.20
# Training model with   4 hidden variables
# Epoch     0, train loss 2.248778, train error 85.18,  test loss 2.244498, test error 84.15
# Epoch   100, train loss 1.775109, train error 65.30,  test loss 1.616940, test error 63.92
# Epoch   200, train loss 1.760825, train error 65.55,  test loss 1.605961, test error 63.72
# Epoch   300, train loss 1.755203, train error 64.82,  test loss 1.599809, test error 63.20
# Epoch   400, train loss 1.753419, train error 65.57,  test loss 1.603008, test error 62.83
# Epoch   500, train loss 1.749440, train error 65.40,  test loss 1.599888, test error 62.65
# Epoch   600, train loss 1.749889, train error 65.90,  test loss 1.599847, test error 62.97
# Epoch   700, train loss 1.747430, train error 65.88,  test loss 1.600584, test error 62.72
# Epoch   800, train loss 1.748302, train error 65.12,  test loss 1.601308, test error 62.55
# Epoch   900, train loss 1.748796, train error 65.28,  test loss 1.598956, test error 63.10
# Training model with   6 hidden variables
# Epoch     0, train loss 2.312945, train error 88.50,  test loss 2.311788, test error 88.68
# Epoch   100, train loss 1.695133, train error 60.85,  test loss 1.549171, test error 58.35
# Epoch   200, train loss 1.654817, train error 57.90,  test loss 1.510791, test error 57.38
# Epoch   300, train loss 1.585814, train error 53.35,  test loss 1.411454, test error 51.83
# Epoch   400, train loss 1.572944, train error 53.17,  test loss 1.411169, test error 52.33
# Epoch   500, train loss 1.581218, train error 53.72,  test loss 1.432252, test error 52.45
# Epoch   600, train loss 1.573626, train error 53.60,  test loss 1.420303, test error 52.78
# Epoch   700, train loss 1.562210, train error 53.25,  test loss 1.413592, test error 52.15
# Epoch   800, train loss 1.566314, train error 53.60,  test loss 1.416752, test error 52.03
# Epoch   900, train loss 1.561140, train error 53.40,  test loss 1.423914, test error 52.92
# Training model with   8 hidden variables
# Epoch     0, train loss 2.273991, train error 85.68,  test loss 2.265907, test error 85.07
# Epoch   100, train loss 1.553414, train error 54.55,  test loss 1.399709, test error 53.45
# Epoch   200, train loss 1.477502, train error 51.10,  test loss 1.314118, test error 49.75
# Epoch   300, train loss 1.458121, train error 50.00,  test loss 1.303855, test error 49.25
# Epoch   400, train loss 1.456472, train error 50.00,  test loss 1.303977, test error 49.53
# Epoch   500, train loss 1.450205, train error 49.72,  test loss 1.304566, test error 48.60
# Epoch   600, train loss 1.441683, train error 48.72,  test loss 1.297544, test error 48.35
# Epoch   700, train loss 1.440959, train error 48.78,  test loss 1.309222, test error 48.65
# Epoch   800, train loss 1.438251, train error 49.47,  test loss 1.311510, test error 49.08
# Epoch   900, train loss 1.434391, train error 49.12,  test loss 1.307206, test error 48.95
# Training model with  10 hidden variables
# Epoch     0, train loss 2.271534, train error 87.03,  test loss 2.271359, test error 87.25
# Epoch   100, train loss 1.528062, train error 52.00,  test loss 1.345081, test error 51.00
# Epoch   200, train loss 1.442341, train error 48.22,  test loss 1.313567, test error 48.40
# Epoch   300, train loss 1.422774, train error 47.00,  test loss 1.310600, test error 48.75
# Epoch   400, train loss 1.416742, train error 47.30,  test loss 1.316305, test error 49.50
# Epoch   500, train loss 1.402946, train error 47.35,  test loss 1.305423, test error 48.53
# Epoch   600, train loss 1.389639, train error 46.20,  test loss 1.306854, test error 48.30
# Epoch   700, train loss 1.381525, train error 46.17,  test loss 1.308149, test error 48.03
# Epoch   800, train loss 1.377758, train error 45.60,  test loss 1.319373, test error 48.35
# Epoch   900, train loss 1.374248, train error 45.65,  test loss 1.321830, test error 48.10
# Training model with  14 hidden variables
# Epoch     0, train loss 2.217237, train error 83.32,  test loss 2.185140, test error 83.57
# Epoch   100, train loss 1.449111, train error 49.55,  test loss 1.346681, test error 50.17
# Epoch   200, train loss 1.344139, train error 45.47,  test loss 1.292789, test error 46.03
# Epoch   300, train loss 1.310331, train error 44.47,  test loss 1.297681, test error 47.17
# Epoch   400, train loss 1.280327, train error 43.12,  test loss 1.317582, test error 47.95
# Epoch   500, train loss 1.273512, train error 43.22,  test loss 1.343119, test error 48.83
# Epoch   600, train loss 1.255981, train error 43.30,  test loss 1.362849, test error 49.45
# Epoch   700, train loss 1.252100, train error 43.72,  test loss 1.373812, test error 48.95
# Epoch   800, train loss 1.247538, train error 42.83,  test loss 1.394878, test error 49.53
# Epoch   900, train loss 1.245518, train error 42.70,  test loss 1.402113, test error 50.42
# Training model with  18 hidden variables
# Epoch     0, train loss 2.189674, train error 80.75,  test loss 2.153453, test error 79.85
# Epoch   100, train loss 1.319260, train error 44.22,  test loss 1.275550, test error 47.60
# Epoch   200, train loss 1.228266, train error 41.12,  test loss 1.331374, test error 48.70
# Epoch   300, train loss 1.176281, train error 39.03,  test loss 1.349173, test error 48.08
# Epoch   400, train loss 1.149677, train error 38.85,  test loss 1.389417, test error 49.28
# Epoch   500, train loss 1.132163, train error 38.42,  test loss 1.416763, test error 48.62
# Epoch   600, train loss 1.124863, train error 38.15,  test loss 1.423063, test error 48.90
# Epoch   700, train loss 1.107607, train error 38.05,  test loss 1.463594, test error 49.47
# Epoch   800, train loss 1.106199, train error 37.17,  test loss 1.480264, test error 48.92
# Epoch   900, train loss 1.098073, train error 37.65,  test loss 1.515620, test error 50.25
# Training model with  22 hidden variables
# Epoch     0, train loss 2.138833, train error 78.50,  test loss 2.111067, test error 78.47
# Epoch   100, train loss 1.269286, train error 42.45,  test loss 1.305699, test error 48.78
# Epoch   200, train loss 1.141142, train error 37.75,  test loss 1.370548, test error 49.10
# Epoch   300, train loss 1.089542, train error 36.58,  test loss 1.431051, test error 49.70
# Epoch   400, train loss 1.068860, train error 35.70,  test loss 1.487139, test error 49.50
# Epoch   500, train loss 1.037171, train error 34.50,  test loss 1.505133, test error 49.95
# Epoch   600, train loss 1.028076, train error 35.10,  test loss 1.557671, test error 50.90
# Epoch   700, train loss 1.025364, train error 34.95,  test loss 1.615848, test error 52.50
# Epoch   800, train loss 1.011388, train error 34.32,  test loss 1.663072, test error 52.08
# Epoch   900, train loss 0.995381, train error 33.97,  test loss 1.701539, test error 52.15
# Training model with  26 hidden variables
# Epoch     0, train loss 2.104008, train error 79.18,  test loss 2.044876, test error 78.18
# Epoch   100, train loss 1.163669, train error 38.62,  test loss 1.309575, test error 48.80
# Epoch   200, train loss 1.016996, train error 33.68,  test loss 1.435151, test error 49.92
# Epoch   300, train loss 0.971417, train error 33.65,  test loss 1.592556, test error 51.25
# Epoch   400, train loss 0.912403, train error 31.38,  test loss 1.658448, test error 51.85
# Epoch   500, train loss 0.890790, train error 30.30,  test loss 1.746807, test error 51.95
# Epoch   600, train loss 0.874627, train error 30.15,  test loss 1.805825, test error 52.25
# Epoch   700, train loss 0.868894, train error 31.05,  test loss 1.878357, test error 52.80
# Epoch   800, train loss 0.856938, train error 28.70,  test loss 1.932782, test error 53.33
# Epoch   900, train loss 0.828921, train error 28.80,  test loss 2.006202, test error 53.50
# Training model with  30 hidden variables
# Epoch     0, train loss 2.247912, train error 81.82,  test loss 2.252944, test error 83.25
# Epoch   100, train loss 1.140935, train error 37.92,  test loss 1.404198, test error 51.10
# Epoch   200, train loss 0.957533, train error 31.90,  test loss 1.586861, test error 53.00
# Epoch   300, train loss 0.862140, train error 28.53,  test loss 1.755810, test error 53.88
# Epoch   400, train loss 0.814677, train error 27.35,  test loss 1.957617, test error 54.60
# Epoch   500, train loss 0.761921, train error 25.70,  test loss 2.181401, test error 55.60
# Epoch   600, train loss 0.737899, train error 25.00,  test loss 2.388795, test error 56.03
# Epoch   700, train loss 0.697471, train error 23.43,  test loss 2.533999, test error 56.80
# Epoch   800, train loss 0.706624, train error 24.10,  test loss 2.687159, test error 55.83
# Epoch   900, train loss 0.709854, train error 24.78,  test loss 2.840302, test error 56.67
# Training model with  35 hidden variables
# Epoch     0, train loss 2.110276, train error 79.15,  test loss 2.052850, test error 77.60
# Epoch   100, train loss 1.018082, train error 34.18,  test loss 1.383175, test error 50.00
# Epoch   200, train loss 0.770347, train error 25.10,  test loss 1.693169, test error 51.20
# Epoch   300, train loss 0.646811, train error 21.07,  test loss 2.094100, test error 52.58
# Epoch   400, train loss 0.604985, train error 20.00,  test loss 2.457324, test error 52.92
# Epoch   500, train loss 0.531601, train error 16.70,  test loss 2.772922, test error 54.40
# Epoch   600, train loss 0.532557, train error 17.47,  test loss 3.139382, test error 54.95
# Epoch   700, train loss 0.481593, train error 16.18,  test loss 3.511691, test error 55.83
# Epoch   800, train loss 0.438117, train error 14.07,  test loss 3.800675, test error 56.42
# Epoch   900, train loss 0.444121, train error 15.25,  test loss 4.049445, test error 56.47
# Training model with  40 hidden variables
# Epoch     0, train loss 2.198873, train error 82.12,  test loss 2.185875, test error 82.38
# Epoch   100, train loss 0.956774, train error 30.97,  test loss 1.493995, test error 50.80
# Epoch   200, train loss 0.667220, train error 21.00,  test loss 1.893248, test error 52.47
# Epoch   300, train loss 0.505420, train error 15.90,  test loss 2.543607, test error 54.45
# Epoch   400, train loss 0.403873, train error 12.85,  test loss 3.223683, test error 55.08
# Epoch   500, train loss 0.376260, train error 12.90,  test loss 4.040080, test error 57.58
# Epoch   600, train loss 0.319700, train error 11.12,  test loss 4.770105, test error 57.42
# Epoch   700, train loss 0.265109, train error 8.25,  test loss 5.461775, test error 56.95
# Epoch   800, train loss 0.250419, train error 8.07,  test loss 6.233294, test error 57.85
# Epoch   900, train loss 0.292452, train error 10.15,  test loss 6.887649, test error 59.30
# Training model with  45 hidden variables
# Epoch     0, train loss 2.068143, train error 77.15,  test loss 2.012853, test error 76.80
# Epoch   100, train loss 0.826272, train error 27.30,  test loss 1.491829, test error 50.55
# Epoch   200, train loss 0.501007, train error 15.95,  test loss 2.249722, test error 53.50
# Epoch   300, train loss 0.350084, train error 11.68,  test loss 3.277303, test error 54.53
# Epoch   400, train loss 0.236367, train error 7.60,  test loss 4.495410, test error 56.25
# Epoch   500, train loss 0.261849, train error 8.55,  test loss 5.790719, test error 57.58
# Epoch   600, train loss 0.105337, train error 3.20,  test loss 6.751399, test error 55.83
# Epoch   700, train loss 0.017175, train error 0.00,  test loss 7.975439, test error 55.85
# Epoch   800, train loss 0.011134, train error 0.00,  test loss 8.786527, test error 55.90
# Epoch   900, train loss 0.007943, train error 0.00,  test loss 9.380065, test error 55.83
# Training model with  50 hidden variables
# Epoch     0, train loss 2.090702, train error 78.93,  test loss 2.058420, test error 77.90
# Epoch   100, train loss 0.671535, train error 21.30,  test loss 1.553997, test error 49.00
# Epoch   200, train loss 0.323489, train error 9.53,  test loss 2.653597, test error 52.65
# Epoch   300, train loss 0.114862, train error 1.80,  test loss 4.148602, test error 54.17
# Epoch   400, train loss 0.027558, train error 0.03,  test loss 5.688503, test error 54.40
# Epoch   500, train loss 0.012383, train error 0.00,  test loss 6.590902, test error 55.03
# Epoch   600, train loss 0.007999, train error 0.00,  test loss 7.187171, test error 55.00
# Epoch   700, train loss 0.005724, train error 0.00,  test loss 7.636386, test error 55.00
# Epoch   800, train loss 0.004430, train error 0.00,  test loss 8.000087, test error 55.15
# Epoch   900, train loss 0.003625, train error 0.00,  test loss 8.298019, test error 55.12
# Training model with  55 hidden variables
# Epoch     0, train loss 2.093355, train error 79.57,  test loss 2.062989, test error 78.47
# Epoch   100, train loss 0.622746, train error 18.65,  test loss 1.599566, test error 49.35
# Epoch   200, train loss 0.197149, train error 4.03,  test loss 2.900691, test error 53.33
# Epoch   300, train loss 0.037198, train error 0.00,  test loss 4.541023, test error 53.08
# Epoch   400, train loss 0.014868, train error 0.00,  test loss 5.525717, test error 53.30
# Epoch   500, train loss 0.008598, train error 0.00,  test loss 6.111164, test error 53.08
# Epoch   600, train loss 0.005923, train error 0.00,  test loss 6.558334, test error 53.40
# Epoch   700, train loss 0.004437, train error 0.00,  test loss 6.902731, test error 53.45
# Epoch   800, train loss 0.003512, train error 0.00,  test loss 7.170351, test error 53.55
# Epoch   900, train loss 0.002882, train error 0.00,  test loss 7.405386, test error 53.67
# Training model with  60 hidden variables
# Epoch     0, train loss 2.067213, train error 76.43,  test loss 2.021055, test error 77.22
# Epoch   100, train loss 0.484500, train error 14.47,  test loss 1.772752, test error 50.55
# Epoch   200, train loss 0.071753, train error 0.25,  test loss 3.449828, test error 52.83
# Epoch   300, train loss 0.017078, train error 0.00,  test loss 4.585243, test error 53.17
# Epoch   400, train loss 0.008554, train error 0.00,  test loss 5.178586, test error 53.55
# Epoch   500, train loss 0.005533, train error 0.00,  test loss 5.585829, test error 53.58
# Epoch   600, train loss 0.004019, train error 0.00,  test loss 5.887198, test error 53.58
# Epoch   700, train loss 0.003104, train error 0.00,  test loss 6.128098, test error 53.62
# Epoch   800, train loss 0.002507, train error 0.00,  test loss 6.330794, test error 53.70
# Epoch   900, train loss 0.002086, train error 0.00,  test loss 6.501452, test error 53.85
# Training model with  70 hidden variables
# Epoch     0, train loss 2.055631, train error 75.50,  test loss 2.005072, test error 76.10
# Epoch   100, train loss 0.397458, train error 11.35,  test loss 1.933305, test error 53.20
# Epoch   200, train loss 0.038766, train error 0.05,  test loss 3.591684, test error 53.70
# Epoch   300, train loss 0.011521, train error 0.00,  test loss 4.446592, test error 54.12
# Epoch   400, train loss 0.006385, train error 0.00,  test loss 4.923327, test error 54.33
# Epoch   500, train loss 0.004259, train error 0.00,  test loss 5.236485, test error 54.20
# Epoch   600, train loss 0.003139, train error 0.00,  test loss 5.479894, test error 54.25
# Epoch   700, train loss 0.002446, train error 0.00,  test loss 5.675547, test error 54.20
# Epoch   800, train loss 0.001996, train error 0.00,  test loss 5.839017, test error 54.17
# Epoch   900, train loss 0.001672, train error 0.00,  test loss 5.978467, test error 54.40
# Training model with  80 hidden variables
# Epoch     0, train loss 2.017335, train error 75.03,  test loss 1.957394, test error 76.03
# Epoch   100, train loss 0.256606, train error 5.25,  test loss 2.090250, test error 51.35
# Epoch   200, train loss 0.019939, train error 0.00,  test loss 3.501014, test error 52.12
# Epoch   300, train loss 0.007887, train error 0.00,  test loss 4.067999, test error 52.50
# Epoch   400, train loss 0.004642, train error 0.00,  test loss 4.402926, test error 52.33
# Epoch   500, train loss 0.003222, train error 0.00,  test loss 4.642741, test error 52.33
# Epoch   600, train loss 0.002435, train error 0.00,  test loss 4.829968, test error 52.47
# Epoch   700, train loss 0.001932, train error 0.00,  test loss 4.982517, test error 52.60
# Epoch   800, train loss 0.001594, train error 0.00,  test loss 5.110282, test error 52.65
# Epoch   900, train loss 0.001348, train error 0.00,  test loss 5.221562, test error 52.55
# Training model with  90 hidden variables
# Epoch     0, train loss 2.020932, train error 74.88,  test loss 1.960622, test error 75.20
# Epoch   100, train loss 0.131766, train error 0.82,  test loss 2.163392, test error 50.70
# Epoch   200, train loss 0.014295, train error 0.00,  test loss 3.170105, test error 50.97
# Epoch   300, train loss 0.006402, train error 0.00,  test loss 3.577749, test error 51.17
# Epoch   400, train loss 0.003936, train error 0.00,  test loss 3.834615, test error 51.28
# Epoch   500, train loss 0.002772, train error 0.00,  test loss 4.015807, test error 51.10
# Epoch   600, train loss 0.002113, train error 0.00,  test loss 4.161794, test error 51.03
# Epoch   700, train loss 0.001693, train error 0.00,  test loss 4.278912, test error 51.05
# Epoch   800, train loss 0.001403, train error 0.00,  test loss 4.379365, test error 51.00
# Epoch   900, train loss 0.001192, train error 0.00,  test loss 4.465230, test error 51.03
# Training model with 100 hidden variables
# Epoch     0, train loss 2.001771, train error 74.35,  test loss 1.935278, test error 73.75
# Epoch   100, train loss 0.097809, train error 0.28,  test loss 2.178350, test error 50.33
# Epoch   200, train loss 0.012175, train error 0.00,  test loss 3.027422, test error 51.12
# Epoch   300, train loss 0.005673, train error 0.00,  test loss 3.389594, test error 51.08
# Epoch   400, train loss 0.003536, train error 0.00,  test loss 3.615455, test error 51.08
# Epoch   500, train loss 0.002517, train error 0.00,  test loss 3.781243, test error 51.15
# Epoch   600, train loss 0.001930, train error 0.00,  test loss 3.910930, test error 51.15
# Epoch   700, train loss 0.001550, train error 0.00,  test loss 4.016652, test error 51.17
# Epoch   800, train loss 0.001287, train error 0.00,  test loss 4.107491, test error 51.25
# Epoch   900, train loss 0.001096, train error 0.00,  test loss 4.186120, test error 51.30
# Training model with 120 hidden variables
# Epoch     0, train loss 1.963248, train error 73.32,  test loss 1.890283, test error 74.12
# Epoch   100, train loss 0.052492, train error 0.00,  test loss 2.125391, test error 48.50
# Epoch   200, train loss 0.009532, train error 0.00,  test loss 2.694891, test error 48.75
# Epoch   300, train loss 0.004715, train error 0.00,  test loss 2.951426, test error 48.70
# Epoch   400, train loss 0.003020, train error 0.00,  test loss 3.122302, test error 48.88
# Epoch   500, train loss 0.002172, train error 0.00,  test loss 3.245735, test error 48.97
# Epoch   600, train loss 0.001679, train error 0.00,  test loss 3.342740, test error 48.78
# Epoch   700, train loss 0.001357, train error 0.00,  test loss 3.423872, test error 48.75
# Epoch   800, train loss 0.001133, train error 0.00,  test loss 3.492923, test error 48.80
# Epoch   900, train loss 0.000969, train error 0.00,  test loss 3.552270, test error 48.70
# Training model with 140 hidden variables
# Epoch     0, train loss 1.966479, train error 72.47,  test loss 1.890550, test error 73.35
# Epoch   100, train loss 0.036524, train error 0.00,  test loss 2.109461, test error 48.35
# Epoch   200, train loss 0.008114, train error 0.00,  test loss 2.582200, test error 48.78
# Epoch   300, train loss 0.004166, train error 0.00,  test loss 2.803984, test error 48.67
# Epoch   400, train loss 0.002705, train error 0.00,  test loss 2.951680, test error 48.67
# Epoch   500, train loss 0.001967, train error 0.00,  test loss 3.059469, test error 48.65
# Epoch   600, train loss 0.001530, train error 0.00,  test loss 3.146725, test error 48.65
# Epoch   700, train loss 0.001242, train error 0.00,  test loss 3.217530, test error 48.55
# Epoch   800, train loss 0.001039, train error 0.00,  test loss 3.278852, test error 48.58
# Epoch   900, train loss 0.000890, train error 0.00,  test loss 3.331912, test error 48.58
# Training model with 160 hidden variables
# Epoch     0, train loss 1.931759, train error 71.12,  test loss 1.850847, test error 71.72
# Epoch   100, train loss 0.027799, train error 0.00,  test loss 2.073189, test error 47.78
# Epoch   200, train loss 0.006972, train error 0.00,  test loss 2.474020, test error 47.65
# Epoch   300, train loss 0.003672, train error 0.00,  test loss 2.669548, test error 47.58
# Epoch   400, train loss 0.002416, train error 0.00,  test loss 2.798173, test error 47.53
# Epoch   500, train loss 0.001773, train error 0.00,  test loss 2.894758, test error 47.65
# Epoch   600, train loss 0.001384, train error 0.00,  test loss 2.971553, test error 47.67
# Epoch   700, train loss 0.001129, train error 0.00,  test loss 3.036057, test error 47.58
# Epoch   800, train loss 0.000948, train error 0.00,  test loss 3.091088, test error 47.70
# Epoch   900, train loss 0.000814, train error 0.00,  test loss 3.139077, test error 47.65
# Training model with 180 hidden variables
# Epoch     0, train loss 1.917316, train error 71.25,  test loss 1.846532, test error 71.47
# Epoch   100, train loss 0.024318, train error 0.00,  test loss 2.081202, test error 48.67
# Epoch   200, train loss 0.006509, train error 0.00,  test loss 2.434839, test error 48.80
# Epoch   300, train loss 0.003491, train error 0.00,  test loss 2.615377, test error 48.88
# Epoch   400, train loss 0.002312, train error 0.00,  test loss 2.735363, test error 48.75
# Epoch   500, train loss 0.001703, train error 0.00,  test loss 2.826974, test error 48.60
# Epoch   600, train loss 0.001333, train error 0.00,  test loss 2.899573, test error 48.65
# Epoch   700, train loss 0.001088, train error 0.00,  test loss 2.960034, test error 48.62
# Epoch   800, train loss 0.000915, train error 0.00,  test loss 3.011850, test error 48.53
# Epoch   900, train loss 0.000786, train error 0.00,  test loss 3.057521, test error 48.62
# Training model with 200 hidden variables
# Epoch     0, train loss 1.957597, train error 72.50,  test loss 1.888743, test error 74.20
# Epoch   100, train loss 0.021287, train error 0.00,  test loss 1.964518, test error 47.72
# Epoch   200, train loss 0.006088, train error 0.00,  test loss 2.281401, test error 47.62
# Epoch   300, train loss 0.003293, train error 0.00,  test loss 2.444043, test error 47.78
# Epoch   400, train loss 0.002194, train error 0.00,  test loss 2.554920, test error 47.70
# Epoch   500, train loss 0.001619, train error 0.00,  test loss 2.637703, test error 47.88
# Epoch   600, train loss 0.001271, train error 0.00,  test loss 2.704378, test error 47.90
# Epoch   700, train loss 0.001039, train error 0.00,  test loss 2.759650, test error 48.03
# Epoch   800, train loss 0.000875, train error 0.00,  test loss 2.806895, test error 48.10
# Epoch   900, train loss 0.000753, train error 0.00,  test loss 2.848849, test error 48.22
# Training model with 250 hidden variables
# Epoch     0, train loss 1.881213, train error 68.47,  test loss 1.798144, test error 69.80
# Epoch   100, train loss 0.017176, train error 0.00,  test loss 1.900116, test error 46.38
# Epoch   200, train loss 0.005344, train error 0.00,  test loss 2.160510, test error 46.47
# Epoch   300, train loss 0.002967, train error 0.00,  test loss 2.296088, test error 46.50
# Epoch   400, train loss 0.002004, train error 0.00,  test loss 2.388620, test error 46.60
# Epoch   500, train loss 0.001492, train error 0.00,  test loss 2.458621, test error 46.58
# Epoch   600, train loss 0.001177, train error 0.00,  test loss 2.515449, test error 46.60
# Epoch   700, train loss 0.000966, train error 0.00,  test loss 2.562514, test error 46.70
# Epoch   800, train loss 0.000816, train error 0.00,  test loss 2.603442, test error 46.62
# Epoch   900, train loss 0.000704, train error 0.00,  test loss 2.639109, test error 46.58
# Training model with 300 hidden variables
# Epoch     0, train loss 1.897418, train error 67.53,  test loss 1.839681, test error 69.88
# Epoch   100, train loss 0.014345, train error 0.00,  test loss 1.892653, test error 47.85
# Epoch   200, train loss 0.004751, train error 0.00,  test loss 2.117939, test error 48.08
# Epoch   300, train loss 0.002697, train error 0.00,  test loss 2.239496, test error 48.00
# Epoch   400, train loss 0.001839, train error 0.00,  test loss 2.322633, test error 47.97
# Epoch   500, train loss 0.001377, train error 0.00,  test loss 2.386676, test error 48.03
# Epoch   600, train loss 0.001092, train error 0.00,  test loss 2.438384, test error 48.00
# Epoch   700, train loss 0.000899, train error 0.00,  test loss 2.481892, test error 47.97
# Epoch   800, train loss 0.000761, train error 0.00,  test loss 2.519158, test error 48.05
# Epoch   900, train loss 0.000657, train error 0.00,  test loss 2.551978, test error 48.08
# Training model with 400 hidden variables
# Epoch     0, train loss 1.839298, train error 65.38,  test loss 1.771093, test error 68.82
# Epoch   100, train loss 0.011643, train error 0.00,  test loss 1.752691, test error 45.97
# Epoch   200, train loss 0.004167, train error 0.00,  test loss 1.929709, test error 45.75
# Epoch   300, train loss 0.002418, train error 0.00,  test loss 2.027992, test error 45.60
# Epoch   400, train loss 0.001666, train error 0.00,  test loss 2.096473, test error 45.78
# Epoch   500, train loss 0.001256, train error 0.00,  test loss 2.149541, test error 45.72
# Epoch   600, train loss 0.001000, train error 0.00,  test loss 2.191830, test error 45.72
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.228080, test error 45.67
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.259141, test error 45.55
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.286527, test error 45.50

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
